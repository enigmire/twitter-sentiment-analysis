# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
import re
from nltk.corpus import stopwords
import string

# %%
pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.8.2.2-cp39-cp39-win_amd64.whl (153 kB)
# Requirement already satisfied: matplotlib in c:\users\iyanu egbuwalo\anaconda3\lib\site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\iyanu egbuwalo\anaconda3\lib\site-packages (from wordcloud) (1.21.5)
# Requirement already satisfied: pillow in c:\users\iyanu egbuwalo\anaconda3\lib\site-packages (from wordcloud) (9.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\iyanu egbuwalo\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\iyanu egbuwalo\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\iyanu egbuwalo\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\iyanu egbuwalo\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\iyanu egbuwalo\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\iyanu egbuwalo\anaconda3\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: six>=1.5 in c:\users\iyanu egbuwalo\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.2.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
data = pd.read_csv("C:/Users/IYANU Egbuwalo/Downloads/archive/filename.csv")

# %%
print(data.head())
# Out:
#              id  conversation_id               created_at        date  \
# 0  1.597390e+18     1.597060e+18  2022-11-29 00:47:13 UTC  29/11/2022
# 1  1.597390e+18     1.597320e+18  2022-11-29 00:47:10 UTC  29/11/2022
# 2  1.597390e+18     1.597320e+18  2022-11-29 00:47:08 UTC  29/11/2022
# 3  1.597390e+18     1.597020e+18  2022-11-29 00:47:07 UTC  29/11/2022
# 4  1.597390e+18     1.597360e+18  2022-11-29 00:47:07 UTC  29/11/2022
#
#        time  timezone       user_id    username               name place  ...  \
# 0  00:47:13         0  1.469470e+18  shawneng10     ~natfes-todnes   NaN  ...
# 1  00:47:10         0  8.628942e+06     marcjef            marcjef   NaN  ...
# 2  00:47:08         0  1.497150e+18  tballs4375            T Balls   NaN  ...
# 3  00:47:07         0  1.266480e+18      amtrpa  Transhumanist Ben   NaN  ...
# 4  00:47:07         0  1.518590e+18    nwrewind            Phil d.   NaN  ...
#
#   geo source user_rt_id user_rt retweet_id  \
# 0 NaN    NaN        NaN     NaN        NaN
# 1 NaN    NaN        NaN     NaN        NaN
# 2 NaN    NaN        NaN     NaN        NaN
# 3 NaN    NaN        NaN     NaN        NaN
# 4 NaN    NaN        NaN     NaN        NaN
#
#                                             reply_to  retweet_date  translate  \
# 0  [{'screen_name': 'PalmerReport', 'name': 'Palm...           NaN        NaN
# 1  [{'screen_name': 'AlishbaBaigPTI', 'name': 'Al...           NaN        NaN
# 2  [{'screen_name': 'RJ_Macnaughton', 'name': 'Co...           NaN        NaN
# 3  [{'screen_name': 'anderssandberg', 'name': 'An...           NaN        NaN
# 4  [{'screen_name': 'lockwoodwes', 'name': 'wes l...           NaN        NaN
#
#   trans_src trans_dest
# 0       NaN        NaN
# 1       NaN        NaN
# 2       NaN        NaN
# 3       NaN        NaN
# 4       NaN        NaN
#
# [5 rows x 36 columns]

# %% [markdown]
# checking out the columns

# %%
print(data.columns)
# Out:
# Index(['id', 'conversation_id', 'created_at', 'date', 'time', 'timezone',
#        'user_id', 'username', 'name', 'place', 'tweet', 'language', 'mentions',
#        'urls', 'photos', 'replies_count', 'retweets_count', 'likes_count',
#        'hashtags', 'cashtags', 'link', 'retweet', 'quote_url', 'video',
#        'thumbnail', 'near', 'geo', 'source', 'user_rt_id', 'user_rt',
#        'retweet_id', 'reply_to', 'retweet_date', 'translate', 'trans_src',
#        'trans_dest'],
#       dtype='object')

# %%
data = data[["username", "tweet", "language"]]

# %%
## checking if there are nulls in the column

data.isnull().sum()
# Out:
# username    0
# tweet       0
# language    0
# dtype: int64

# %%
data["language"].value_counts()
# Out:
# en     8628
# pt      403
# it      191
# qme     176
# ru      117
# und      79
# ja       71
# in       55
# es       53
# ca       21
# ar       20
# de       20
# fr       20
# th       17
# fi       14
# sr       14
# nl       12
# qht      12
# vi       10
# pl        6
# et        6
# tr        5
# zxx       5
# el        4
# qam       4
# bn        4
# uk        4
# zh        4
# ro        4
# tl        3
# cs        3
# fa        3
# da        3
# ko        2
# art       1
# hi        1
# sv        1
# bg        1
# ht        1
# qst       1
# ur        1
# cy        1
# lv        1
# Name: language, dtype: int64

# %%
## most of the tweets are in English which is a good thing for us.
## now we can prepare the task for sentiment analysis
## links, punctuations, symbols and other language errors are removed from the tweet

# %%
nltk.download('stopwords')
stemmer = nltk.SnowballStemmer("english")
stopword = set(stopwords.words("english"))

def clean(text):
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://S+|www.\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = [word for word in text.split(' ') if word not in stopword]
    text = " ".join(text)
    text = [stemmer.stem(word) for word in text.split(' ')]
    text = " ".join(text)
    return text
data["tweet"] = data["tweet"].apply(clean)
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\IYANU
# [nltk_data]     Egbuwalo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
## now we check out the most used words

text = " ".join(i for i in data.tweet)
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords = stopwords, background_color = "white").generate(text)
##wordcloud = WordCloud().generate(text)

plt.figure(figsize = (15,10))
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis("off")
plt.show()
